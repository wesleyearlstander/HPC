# %%
import matplotlib.pyplot as plt
from skimage.color import rgb2gray

# %%
SeqA = plt.imread('images/sequential_lena_bw_average.pgm')
SeqS = plt.imread('images/sequential_lena_bw_sharpen.pgm')
SeqE = plt.imread('images/sequential_lena_bw_edge.pgm')
plt.gray()

# %%
fig, axs = plt.subplots(1,3,figsize=(15,5))
[axi.set_axis_off() for axi in axs.ravel()]
axs[0] = fig.add_subplot(1,3,1)
axs[0].set_title("Sequential Averaging Filter 3x3")
axs[0].imshow(plt.imread('images/sequential_lena_bw_average.pgm'),  vmin = 0, vmax= 255)
plt.axis('off')
axs[1] = fig.add_subplot(1,3,2)
axs[1].set_title("Sequential Edge Filter 3x3")
axs[1].imshow(plt.imread('images/sequential_lena_bw_edge.pgm'),  vmin = 0, vmax= 255)
plt.axis('off')
axs[1] = fig.add_subplot(1,3,3)
axs[1].set_title("Sequential Sharpening Filter 3x3")
axs[1].imshow(plt.imread('images/sequential_lena_bw_sharpen.pgm'),  vmin = 0, vmax= 255)
plt.axis('off')
fig.savefig("images/sequentialResults.jpg")

# %%
fig, axs = plt.subplots(1,3,figsize=(15,5))
[axi.set_axis_off() for axi in axs.ravel()]
axs[0] = fig.add_subplot(1,3,1)
axs[0].set_title("Global Averaging Filter 3x3")
axs[0].imshow(plt.imread('images/global_lena_bw_average.pgm'),  vmin = 0, vmax= 255)
plt.axis('off')
axs[1] = fig.add_subplot(1,3,2)
axs[1].set_title("Global Edge Filter 3x3")
axs[1].imshow(plt.imread('images/global_lena_bw_edge.pgm'),  vmin = 0, vmax= 255)
plt.axis('off')
axs[1] = fig.add_subplot(1,3,3)
axs[1].set_title("Global Sharpening Filter 3x3")
axs[1].imshow(plt.imread('images/global_lena_bw_sharpen.pgm'),  vmin = 0, vmax= 255)
plt.axis('off')
fig.savefig("images/globalResults.jpg")

# %%
fig, axs = plt.subplots(1,3,figsize=(15,5))
[axi.set_axis_off() for axi in axs.ravel()]
axs[0] = fig.add_subplot(1,3,1)
axs[0].set_title("Shared-Strided Averaging Filter 3x3")
axs[0].imshow(plt.imread('images/shared_lena_bw_average_strided.pgm'),  vmin = 0, vmax= 255)
plt.axis('off')
axs[1] = fig.add_subplot(1,3,2)
axs[1].set_title("Shared-Strided Edge Filter 3x3")
axs[1].imshow(plt.imread('images/shared_lena_bw_edge_strided.pgm'),  vmin = 0, vmax= 255)
plt.axis('off')
axs[1] = fig.add_subplot(1,3,3)
axs[1].set_title("Shared-Strided Sharpening Filter 3x3")
axs[1].imshow(plt.imread('images/shared_lena_bw_sharpen_strided.pgm'),  vmin = 0, vmax= 255)
plt.axis('off')
fig.savefig("images/sharedStridedResults.jpg")

# %%
fig, axs = plt.subplots(1,3,figsize=(15,5))
[axi.set_axis_off() for axi in axs.ravel()]
axs[0] = fig.add_subplot(1,3,1)
axs[0].set_title("Shared-Tiled Averaging Filter 3x3")
axs[0].imshow(plt.imread('images/shared_lena_bw_average_tiled.pgm'),  vmin = 0, vmax= 255)
plt.axis('off')
axs[1] = fig.add_subplot(1,3,2)
axs[1].set_title("Shared-Tiled Edge Filter 3x3")
axs[1].imshow(plt.imread('images/shared_lena_bw_edge_tiled.pgm'),  vmin = 0, vmax= 255)
plt.axis('off')
axs[1] = fig.add_subplot(1,3,3)
axs[1].set_title("Shared-Tiled Sharpening Filter 3x3")
axs[1].imshow(plt.imread('images/shared_lena_bw_sharpen_tiled.pgm'),  vmin = 0, vmax= 255)
plt.axis('off')
fig.savefig("images/sharedTiledResults.jpg")

# %%
fig, axs = plt.subplots(1,3,figsize=(15,5))
[axi.set_axis_off() for axi in axs.ravel()]
axs[0] = fig.add_subplot(1,3,1)
axs[0].set_title("2D Texture Averaging Filter 3x3")
axs[0].imshow(plt.imread('images/texture_lena_bw_average.pgm'),  vmin = 0, vmax= 255)
plt.axis('off')
axs[1] = fig.add_subplot(1,3,2)
axs[1].set_title("2D Texture Edge Filter 3x3")
axs[1].imshow(plt.imread('images/texture_lena_bw_edge.pgm'),  vmin = 0, vmax= 255)
plt.axis('off')
axs[1] = fig.add_subplot(1,3,3)
axs[1].set_title("2D Texture Sharpening Filter 3x3")
axs[1].imshow(plt.imread('images/texture_lena_bw_sharpen.pgm'),  vmin = 0, vmax= 255)
plt.axis('off')
fig.savefig("images/texture2DResults.jpg")

# %%
fig, axs = plt.subplots(1,3,figsize=(15,5))
[axi.set_axis_off() for axi in axs.ravel()]
axs[0] = fig.add_subplot(1,3,1)
axs[0].set_title("1D Texture Averaging Filter 3x3")
axs[0].imshow(plt.imread('images/texture1_lena_bw_average.pgm'),  vmin = 0, vmax= 255)
plt.axis('off')
axs[1] = fig.add_subplot(1,3,2)
axs[1].set_title("1D Texture Edge Filter 3x3")
axs[1].imshow(plt.imread('images/texture1_lena_bw_edge.pgm'),  vmin = 0, vmax= 255)
plt.axis('off')
axs[1] = fig.add_subplot(1,3,3)
axs[1].set_title("1D Texture Sharpening Filter 3x3")
axs[1].imshow(plt.imread('images/texture1_lena_bw_sharpen.pgm'),  vmin = 0, vmax= 255)
plt.axis('off')
fig.savefig("images/texture1DResults.jpg")

# %%
fig, axs = plt.subplots(1,3,figsize=(15,5))
[axi.set_axis_off() for axi in axs.ravel()]
axs[0] = fig.add_subplot(1,3,1)
axs[0].set_title("2D Texture and Constant Averaging Filter 3x3")
axs[0].imshow(plt.imread('images/texturec_lena_bw_average.pgm'),  vmin = 0, vmax= 255)
plt.axis('off')
axs[1] = fig.add_subplot(1,3,2)
axs[1].set_title("2D Texture and Constant Edge Filter 3x3")
axs[1].imshow(plt.imread('images/texturec_lena_bw_edge.pgm'),  vmin = 0, vmax= 255)
plt.axis('off')
axs[1] = fig.add_subplot(1,3,3)
axs[1].set_title("2D Texture and Constant Sharpening Filter 3x3")
axs[1].imshow(plt.imread('images/texturec_lena_bw_sharpen.pgm'),  vmin = 0, vmax= 255)
plt.axis('off')
fig.savefig("images/texture2DConstantResults.jpg")

# %%
fig, axs = plt.subplots(1,3,figsize=(15,5))
[axi.set_axis_off() for axi in axs.ravel()]
axs[0] = fig.add_subplot(1,3,1)
axs[0].set_title("1D Texture and Constant Averaging Filter 3x3")
axs[0].imshow(plt.imread('images/texture1c_lena_bw_average.pgm'),  vmin = 0, vmax= 255)
plt.axis('off')
axs[1] = fig.add_subplot(1,3,2)
axs[1].set_title("1D Texture and Constant Edge Filter 3x3")
axs[1].imshow(plt.imread('images/texture1c_lena_bw_edge.pgm'),  vmin = 0, vmax= 255)
plt.axis('off')
axs[1] = fig.add_subplot(1,3,3)
axs[1].set_title("1D Texture and Constant Sharpening Filter 3x3")
axs[1].imshow(plt.imread('images/texture1c_lena_bw_sharpen.pgm'),  vmin = 0, vmax= 255)
plt.axis('off')
fig.savefig("images/texture1DConstantResults.jpg")

# %%
fig, axs = plt.subplots(1,3,figsize=(15,5))
[axi.set_axis_off() for axi in axs.ravel()]
axs[0] = fig.add_subplot(1,3,1)
axs[0].set_title("2D Texture and Constant Averaging Filter 3x3")
axs[0].imshow(plt.imread('images/texture2cs_lena_bw_average.pgm'),  vmin = 0, vmax= 255)
plt.axis('off')
axs[1] = fig.add_subplot(1,3,2)
axs[1].set_title("2D Texture and Constant Edge Filter 3x3")
axs[1].imshow(plt.imread('images/texture2cs_lena_bw_edge.pgm'),  vmin = 0, vmax= 255)
plt.axis('off')
axs[1] = fig.add_subplot(1,3,3)
axs[1].set_title("2D Texture and Constant Sharpening Filter 3x3")
axs[1].imshow(plt.imread('images/texture2cs_lena_bw_sharpen.pgm'),  vmin = 0, vmax= 255)
plt.axis('off')
fig.savefig("images/texture2DConstantSharedResults.jpg")

# %%
fig, axs = plt.subplots(1,3,figsize=(15,5))
[axi.set_axis_off() for axi in axs.ravel()]
axs[0] = fig.add_subplot(1,3,1)
axs[0].set_title("2D Texture and Constant Averaging Filter 3x3")
axs[0].imshow(plt.imread('images/texture1cs_lena_bw_average.pgm'),  vmin = 0, vmax= 255)
plt.axis('off')
axs[1] = fig.add_subplot(1,3,2)
axs[1].set_title("2D Texture and Constant Edge Filter 3x3")
axs[1].imshow(plt.imread('images/texture1cs_lena_bw_edge.pgm'),  vmin = 0, vmax= 255)
plt.axis('off')
axs[1] = fig.add_subplot(1,3,3)
axs[1].set_title("2D Texture and Constant Sharpening Filter 3x3")
axs[1].imshow(plt.imread('images/texture1cs_lena_bw_sharpen.pgm'),  vmin = 0, vmax= 255)
plt.axis('off')
fig.savefig("images/texture1DConstantSharedResults.jpg")
